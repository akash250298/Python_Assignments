# %%
# Assignment 10: Time Calculations and Prime Number Generator

# %%
# 1. Seconds in an Hour
# Use Python to calculate how many seconds are in one hour.
seconds_per_minute = 60
minutes_per_hour = 60
seconds_in_hour = seconds_per_minute * minutes_per_hour
print("Seconds in an hour:",seconds_in_hour)

# -------------------------------------------------------
# Out:
# Seconds in an hour: 3600

# %%
# 2. Store the Result in a Variable
# Assign the result from Question 1 to a variable called seconds_per_hour and print it.

seconds_per_hour = seconds_in_hour
print("Seconds per hour:",seconds_per_hour)

# -------------------------------------------------------
# Out:
# Seconds per hour: 3600

# %%
# 3. Calculate Seconds in a Day
# Estimate how many seconds are in a day.
hours_per_day = 24
seconds_in_day = seconds_per_hour * hours_per_day
print("Seconds in a day:",seconds_in_day)

# -------------------------------------------------------
# Out:
# Seconds in a day: 86400

# %%
# 4. Save Seconds Per Day in a Variable
# Recalculate the number of seconds in a day and assign the result to a variable called seconds_per_day.
seconds_per_day = seconds_in_day
print("Seconds per day:",seconds_per_day)

# -------------------------------------------------------
# Out:
# Seconds per day: 86400

# %%
# 5. Floating-Point Division
# Divide seconds_per_day by seconds_per_hour using floating-point division (/).
result_float = seconds_per_day / seconds_per_hour
print("Result float:",result_float)

# -------------------------------------------------------
# Out:
# Result float: 24.0

# %%
# 6. Integer Division
# Now divide seconds_per_day by seconds_per_hour using integer division (//).
result_int = seconds_per_day // seconds_per_hour
print("Result int:",result_int)
# QUESTION: Does this value match the previous result aside from the decimal point? => Yes, it does.

# -------------------------------------------------------
# Out:
# Result int: 24

# %%
# 7. Prime Number Generator
# Write a generator function genPrimes() that yields an infinite sequence of prime numbers starting from 2.
# Use a loop to print the first 5 prime numbers generated by genPrimes().

def genPrimes():
    primes = []
    num = 2
    while True:
        is_prime = True
        for p in primes:
            if p * p > num:
                break
            if num % p == 0:
                is_prime = False
                break
        if is_prime:
            primes.append(num)
            yield num
        num += 1

prime_generator = genPrimes()
print("PRIME NUMBERS:")
for _ in range(5):
    print(next(prime_generator))
# Out:
# PRIME NUMBERS:
# 2
# 3
# 5
# 7
# 11
