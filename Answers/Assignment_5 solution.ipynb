# %%
# Assignment 5:
# =====================
# Part 1: Problems on Functions
# =====================

# ➊ Given the temperature of a day in Degrees Celsius, convert this given 
# temperature from Celsius to Fahrenheit. Complete the function to do so. 
# Round the output up to 2 decimal places
# Note:
# ➊ To round up the values 
#   Python : Use round(ans,2) to round up ans to two decimals
# ➋ The formula to convert Celsius to Fahrenheit is: 
#  F = (9/5 * C) + 32
print("Question 1 solution:")
def celsius_farhen(Celsius):
    ans = (Celsius* 9/5)+32
    return round(ans,2)

tempInC = int(input("Enter temparature of the day in Celcius:"))
print("Temperature of Day in Celcius:",tempInC)
print(f"Temperature in Fahrenheit is: {celsius_farhen(tempInC)}")
# Out:
# Question 1 solution:
# Temperature of Day in Celcius: 42
# Temperature in Fahrenheit is: 107.6

# %%
# ➋ Write a program to calculate the total amount if the principal 
# amount, simple interest rate per annum, and time in the number of days 
# are given. The simple interest rate per annum is provided as a percentage. 
# Assuming that there are 365 days in a year, print the total amount rounded 
# up to 2 decimal places.
# Note 1 : Use round(ans,2) to round up ans up to two decimals
print("Question 2 solution:")
def totalSimpleAmount(t, pa, ir):
    # t: time(in no. of days), pa: principal amt, ir: interest rate.
    si = (pa * ir * t)/(365*100) #simple interest
    amt = si + pa #total amount
    return print(f"Total amount is: Rs.{round(amt, 2)}\nFor PA: Rs.{pa}, on IR: {ir}% for time: {t} days.")

print("Total amount based on T, PA and IR.")
time_input = input("Enter the time in days (or HH:MM):")
try:
    # Try to convert directly to int (days)
    time = int(time_input)
except ValueError:
    # If not an int, try to parse as HH:MM
    if ':' in time_input:
        hours, minutes = map(int, time_input.split(':'))
        # Convert hours and minutes to days (1 day = 24 hours)
        time = (hours + minutes / 60) / 24
        # Convert fractional days to actual days (rounded up)
        time = round(time, 2)
    else:
        raise ValueError("Invalid time format. Please enter as days or HH:MM.")

pa = int(input("Enter the Pricipal Amount:"))
ir = int(input("Enter Interest Rate:"))

totalSimpleAmount(time, pa, ir)
# Out:
# Question 2 solution:
# Total amount based on T, PA and IR.
# Total amount is: Rs.5000.96
# For PA: Rs.5000, on IR: 8% for time: 0.88 days.

# %%
print("Question 3 solution:")
# ➌ Write a program that takes the cost price of a vehicle as an argument and 
# returns the road tax, that the vehicle owner has to pay according to the 
# following criteria:
# Note1 : Return the tax up to one decimal place.
def road_tax(price):
    if price > 100000:
        tax = 0.2 * price
    elif (price > 75000 and price <= 100000):
        tax = 0.15 * price
    elif (price > 50000 and price <= 75000):
        tax = 0.1 * price
    else:
        tax = 0.05 * price
    return print(f"Tax for: RS. {price} is: RS.{round(tax,1)}")

cp = int(input("Enter the Cost Price:"))
road_tax(cp)
# Out:
# Question 3 solution:
# Tax for: RS. 25000 is: RS.1250.0

# %%
# ➍ You are given a positive integer A denoting the radius of a circle. You have to calculate the area of the circle. Note: The formula for the area of a circle is Area = πr², where r is the circle's radius. You can use the value of PI as 3.1416. Round up the final answer up to 2 decimal places. You can round(area, 2) for rounding area to 2 decimal places
class Solution:
    # @param A : integer
    # @return an integer
    def solve(self, A):
        # return math.ceil(math.pi*(A**2))
        return round(3.1416*(A**2), 2)
print("Question 4 solution:")
s = Solution()
r = int(input("Enter Radius of the circle:"))
print(f"Area of the circle for radius {r} is: {s.solve(r)}")
# Out:
# Question 4 solution:
# Area of the circle for radius 8 is: 201.06

# %%
# ➎ Given an integer n, write a program to return the sum of squares of first n natural numbers in integer format.
# Note1 :
# The formula for the sum of squares of first n natural numbers is: n(n+1)(2n+1)/6
def sum_squares(n):
    ans = (n*(n+1)*(2*n+1))//6
    # ''' input:Given Integer n
    #      output: Return ans as sum of squares in integer forma '''
    return print(f"Sum of squares for num: {n} is: {ans}")
print("Question 5 solution:")
n = int(input("Enter a number:"))
sum_squares(n)
# Out:
# Question 5 solution:
# Sum of squares for num: 25 is: 5525

# %%
# ➏ You are given a lowercase latin alphabetic character C. You have to tell 
# whether it is a vowel or not.
# The characters 'a', 'e', 'i', 'o', and 'u' are called vowels.
# Note: You just have to write the code inside the function and return the result. 
# The input and output is handled in the backend.
# Problem Constraints:
# C ∈ ['a' - 'z']
# Input Format:
# The input consists of a single character C.
# Output Format:
# Return 1 if the given character is a vowel, else return 0.
def isvowel(C):
    ans = None
    # YOUR CODE GOES HERE
    vowel = "aeiou"
    if C.lower() in vowel:
        return 1
    else:
        return 0
    return ans
print("Question 6 solution:")
c = input("Enter a character: ")
# print(isvowel(c) ? "{c} is a vowel" : "{c} is not a vovwel")
print(isvowel(c))
# Out:
# Question 6 solution:
# 1

# %%
# ➐ Given the height (A) and weight (B) of a person as input in centimetres and 
# kilograms.
# Find the BMI of that person and the classification of the user based on their 
# BMI.
# ➊ Print Underweight if BMI < 18.5
# ➋ Print Normal if BMI lies in the range (18.5, 24.9)
# ➌ Print Overweight if BMI lies in the range (24.9, 29.9)
# ➍ Print Obese if BMI is greater than 29.9
# If x is the weight in kilograms and y is the height in metres.
# Then, BMI is calculated as x/(y*y).
# Note: Use round(BMI,1) to get only one digit after decimal
# Input Format:
# The first line contains the height of the person in centimetres.
# The second line of the input contains the weight of the person in kilograms.
# Output Format:
# The first line of the output contains the classification of a person based on the BMI value.
# The second line of the output contains the BMI value of the person having only one digit after decimal.
def main(height_cm,weight):
    height = height_cm/100
    BMI = (weight/(height * height))
    # YOUR CODE GOES HERE
    # Please take input and print output to standard input/output
    return BMI
def classify(BMI):
    if BMI < 18.5:
        return "Underweight"
    elif 18.5 <= BMI <= 24.9:
        return "Normal"
    elif 24.9 < BMI <= 29.9:
        return "Overweight"
    else:
        return ("Obese")

print("Question 7 solution:")

height_in_cm = int(input("Enter your height in CM: "))
weight_in_kg = int(input("Enter your weight in KG: "))
print(f"BMI for H: {height_in_cm} CM & W: {weight_in_kg} KG")
BMI =  main(height_in_cm,weight_in_kg)
classification = classify(BMI)
rounded_bmi = round(BMI,1)
print("Classification: ",classification)
print("BMI: ",rounded_bmi)
# Out:
# Question 7 solution:
# BMI for H: 176 CM & W: 65 KG
# Classification:  Normal
# BMI:  21.0

# %%
# =====================
# Part 2: Problems in class
# =====================

# ➊ You are given 3 integer angles(in degrees) A, B and C of a triangle. You 
# have to tell whether the triangle is valid or not.
# A triangle is valid if sum of its angles equals to 180.
# NOTE: You have to take the input of 3 sides of triangle from the user.
# A = int(input())
# B = int(input())
# C = int(input())
# if A+B+C == 180:
#     print("1")
# else:
#     print("0")

def isTriangle(a, b, c):
    if a + b + c == 180:
        print("It is a Valid Triangle.")
    else:
        print("It is Not a Valid Triangle.")

a = int(input("Enter First Side: "))
b = int(input("Enter Second Side: "))
c = int(input("Enter Third Side: "))

print("Given sides are:\nA:", a, ", B:", b, ", C:", c)
isTriangle(a, b, c)
# Out:
# Given sides are:
# A: 60 , B: 60 , C: 60
# It is a Valid Triangle.

# %%
# ➋ Write a program to input two numbers(A & B) from user and print the 
# maximum element among A & B.
# Problem Constraints:
# 1 <= A <= 1000000
# 1 <= B <= 1000000
# A = int(input())
# B = int(input())
# if 1 <= A <= 1000000 and 1 <= B <= 1000000:
#     print(max(A, B))

def max(a, b):
    if a > b:
        return a
    else:
        return b
    
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))

print("Numbers are:\n", a, b)

if 1 <= a <= 1000000 and 1 <= b <= 1000000:
    print("Maximum Element is: ",max(a,b))
# Out:
# Numbers are:
#  25 65
# Maximum Element is:  65

# %%
# ➌ You are given the Cost Price C and Selling Price S of a Product. You have to 
# tell whether there is a Profit or Loss. Also, calculate total profit or loss.
# NOTE: It is guaranteed that Cost Price and Selling Price are not equal.
# NOTE: You have to take input of the Cost Price(C) and Selling Price(S) from the user.
# Problem Constraints:
# 1 <= C, S <= 10^9
# C = int(input())
# S = int(input())
# Profit = S - C
# if 1 <= C and S <= 10**9 and C != S and Profit > 1:
#     print(1)
#     print(S - C)
# else:
#     print(-1)
#     print(-(S - C))

def isProfit(c, s):
    profit = s - c
    if 1 <= c and s <= 10**9 and s and profit >1:
        print("PROFIT of Rs.", profit)
    else:
        print("LOSS of Rs.", profit)

c = int(input("Enter the Cost Price:"))
s = int(input("Enter the Selling Price:"))

isProfit(c, s)
# Out:
# PROFIT of Rs. 1100

# %%
# ➍ Given the number N, Categorise the number according to following 
# condition:
# 1. Odd-Positive
# 2. Odd-Negative
# 3. Even-Positive
# 4. Even-Negative
# Note: Intention of problem is to teach you Nested If-Else, so try to 
# solve this problem using nested if-else
# Problem Constraints:
# -10000 <= N <= 10000 and N != 0

N = int(input("Enter a Number:"))
print("Your number is:", N)

if -10000 <= N <= 10000 and N != 0:
    if N < 0 and N % 2 == 0:
        print("Even-Negative")
    elif N > 0 and N % 2 == 0:
        print("Even-Positive")
    elif N < 0 and N % 2 != 0:
        print("Odd-Negative")
    else:
        print("Odd-Positive")
# Out:
# Your number is: 42
# Even-Positive

# %%
# ➋ Problem Description:
# Write a program that accepts T numbers(N) from the user and find reverse of 
# the given number(N).
# Problem Constraints:
# 1 <= T <= 100
# 1 <= N <= 100000000
T = int(input("Enter number of test cases:")) #
print("TEST CASES:", T)

if 1<= T <= 10000:
    for _ in range(T):
        N = int(input())
        print("Digit is:", N)
        reverse = 0
        if 1<= N <= 100000000:
            while N > 0:
                digit = N % 10 
                reverse = reverse * 10 + digit #
                N = N // 10
            print("Reveresed Digis is:",reverse)
        else:
            print("Enter a valid Digit (<= 0 and <= 100000000)")
# Out:
# TEST CASES: 6500
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 12
#      10 if 1<= T <= 10000:
#      11     for _ in range(T):
# ---> 12         N = int(input())
#      13         print("Digit is:", N)
#      14         reverse = 0
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# ➌ Take an integer N as input. Print the following pattern of N lines. For N = 5:
# *     *
# *    *
# *   *
# *  *
# * *
N = int(input("Enter number of lines:"))
for i in range(N, 0, -1):
    for j in range(0, i + 2):
        if j == 0 or j == i + 1:
            print("*", end="")
        else:
            print(" ", end="")
    print()
# Out:
# *     *
# *    *
# *   *
# *  *
# * *

# %%
# ➍ Take an integer N as input, print the corresponding pattern for N.
# For example if N = 5:
# *****
# _****
# __***
# ___**
# ____*
N = int(input("Enter number of lines:"))
for i in range(1, N + 1):
    for j in range(1, N + 1):
        if j < i:
            print(" ", end="")
        else:
            print("*", end="")
    print()
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
# ➎ Take an integer N, print the corresponding Full Pyramid pattern for N.
# For example if N = 5:
#     * 
#    * * 
#   * * * 
#  * * * * 
# * * * * * 
N = int(input("Enter number of lines:"))
for i in range(N):
    print(" " * (N - i - 1) + "* " * (i + 1))
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
# ➏ Take an integer N as input, print the corresponding pattern for N.
# For example if N = 5:
# 1
# 1_
# 1_3
# 1_3_
# 1_3_5
def main():
    n = int(input("Enter number of lines:"))
    for r in range(1, n + 1):
        for j in range(1, r + 1):
            if j % 2 != 0:
                print(j, end="")
            else:
                print("_", end="")
        print()
    return 0
if __name__ == '__main__':
    main()
# Out:
# 1
# 1_
# 1_3
# 1_3_
# 1_3_5

# %%
# ➐ Take an Integer N as input. Print an Inverse half pyramid of N lines.
# For example if N = 5:
# *****
# ****
# ***
# **
# *
N = int(input("Enter number of lines:"))
for i in range(N, 0, -1):
    print("*" * i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
# ➑ Take an integer N as input, print the corresponding pattern for N.
# For example if N = 5:
# ____*
# ___**
# __***
# _****
# *****
N = int(input("Enter number of lines:"))
for i in range(N, 0, -1):
    print(" " * (i - 1) + "*" * (N - i + 1))
# Out:
#     *
#    **
#   ***
#  ****
# *****
